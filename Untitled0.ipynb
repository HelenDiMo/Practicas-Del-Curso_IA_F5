# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenDiMo/Practicas-Del-Curso_IA_F5/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OPERADORES LÓGICOS

# %%
#deficion de la proposición original
calor = True

#Negación de la proposición
negacion = not calor

#imprimir los resultados
print(f"Proposición original. Hace calor: {calor}")
print(f"Negación de la proposición original. Hace calor: {negacion}")
# Out:
# Proposición original. Hace calor: True
# Negación de la proposición original. Hace calor: False
